# %% [markdown]
# # Challenge 2: critique de films
# ---
# ## Structure de l'URL
# ---
# ### Pratique
#
#     . importer la fonction get() du module requests
#     . Assigner l'url de la page à la variable url
#     . Télécharger la page et assigner le résultat à la variable response
#     . Afficher un extrait du résultat

# %%
from requests import get 
url = "http://www.imdb.com/search/title?release_date=2017&sort=num_votes,desc&page=1"
response = get(url)

# %% [markdown]
#     . Importer la classe BeautifulSoup du package bs4
#     . Extraire le code HTML
#     . utiliser la méthode find_all() pour extraire les éléments souhaités

# %%
from bs4 import BeautifulSoup
html_soup = BeautifulSoup(response.content,'html.parser')

movie_containers = html_soup.find_all('div', class_='lister-item mode-advanced')
print(type(movie_containers))
print(len(movie_containers))
# Out:
# <class 'bs4.element.ResultSet'>
# 50

# %% [markdown]
# ## Extraire la data pour un seul film
# ---
# ### Pratique
# ---
#
#     . Extraire l'année de sortie du premier film
#     . Extraire la note IMDB (à convertir en nombre à virgule)
#     . Extraire la note Metacritic (à convertir en entier)
#     . Extraire le nombre de votes (utiliser paramètre attrs)

# %%
# titre du film 
first_movie=movie_containers[0]
first_movie.h3
# Out:
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">1.</span>
# <a href="/title/tt3315342/">Logan</a>
# <span class="lister-item-year text-muted unbold">(2017)</span>
# </h3>

# %%
first_name=first_movie.h3.a.text

# %%
# Année de sortie
first_year=first_movie.h3.find('span',class_='lister-item-year')
#Note IMDB
first_imdb=float(first_movie.strong.text) #  est la balise strong
#Note Metacritic
first_metascore=first_movie.find('span',class_='metascore favorable')
first_metascore=int(first_metascore.text)
# Nombre de votes
first_nv=first_movie.find('span',attrs={'name':'nv'})
first_votes=int(first_nv['data-value'])

# %% [markdown]
# ## Script pour scraper une seule page

# %%
test_movie_metascore=movie_containers[8].find('div',class_='ratings-metascore')

# exemple de film qui n a pas de metascore

# %%
# On crée des listes vides pour toutes nos informations
names=[]
years=[]
imdb_ratings=[]
metascores = []
votes = []

#On reprend notre data movie_containers pour extraire l information
for container in movie_containers: 
    # si le film a une note metacritique on l extrait
    if container.find('div', class_='ratings-metascore') is not None: 
        
        # le titre du film
        name = container.h3.a.text
        names.append(name) # on ajoute chaque élément name dans la liste names
        
        # l'année de sortie
        year=container.h3.find('span',class_='lister-item-year')
        years.append(year.text)
        
        #la note Imdb
        imdb=float(container.strong.text) 
        imdb_ratings.append(imdb)
        
        #Metascore
        m_score=container.find('span',class_='metascore')
        metascores.append(int(m_score.text))
        
        # nombre de votes
        vote = container.find('span',attrs={'name':'nv'})['data-value']
        votes.append(int(vote))

# %% [markdown]
# ## Affichage en Dataframe avec Pandas

# %%
import pandas as pd 
test_df = pd.DataFrame({
          'movie': names,
          'year': years,
          'imdb': imdb_ratings,
          'metascore': metascores,
          'votes': votes
    
})

# %%
print(test_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 5 columns):
# movie        42 non-null object
# year         42 non-null object
# imdb         42 non-null float64
# metascore    42 non-null int64
# votes        42 non-null int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.7+ KB
# None

# %%
test_df
# Out:
#     imdb  metascore                                             movie   votes  \
# 0    8.1         77                                             Logan  426933
# 1    7.6         76                                      Wonder Woman  353480
# 2    7.8         67                    Guardians of the Galaxy Vol. 2  318547
# 3    8.1         94                                           Dunkirk  300114
# 4    7.6         73                            Spider-Man: Homecoming  259622
# 5    7.6         85           Star Wars: Episode VIII - The Last Jedi  256526
# 6    7.7         86                                       Baby Driver  240542
# 7    7.7         84                                           Get Out  220283
# 8    7.6         70                                                It  213707
# 9    7.5         75                              John Wick: Chapter 2  206172
# 10   7.3         65                              Beauty and the Beast  189067
# 11   8.3         81                                 Blade Runner 2049  183697
# 12   6.7         62                                Kong: Skull Island  183034
# 13   8.1         73                                    Thor: Ragnarok  179960
# 14   6.5         65                                   Alien: Covenant  179462
# 15   6.7         39  Pirates of the Caribbean: Dead Men Tell No Tales  167639
# 16   7.0         45                                    Justice League  162234
# 17   6.8         56                           The Fate of the Furious  147415
# 18   7.5         82                    War for the Planet of the Apes  144236
# 19   6.6         54                                              Life  140809
# 20   6.4         52                                Ghost in the Shell  136611
# 21   6.9         41                  King Arthur: Legend of the Sword  129708
# 22   7.0         44                       Kingsman: The Golden Circle  127346
# 23   5.5         34                                         The Mummy  116865
# 24   7.0         47                            The Hitman's Bodyguard  102366
# 25   6.8         63                                     Atomic Blonde   93044
# 26   7.3         75                             The LEGO Batman Movie   89779
# 27   6.6         51       Valerian and the City of a Thousand Planets   89161
# 28   5.2         28                     Transformers: The Last Knight   85491
# 29   5.6         37                                          Baywatch   84748
# 30   7.8         73                                        Wind River   82192
# 31   6.8         74                                           Mother!   78244
# 32   6.0         44                                     Power Rangers   73396
# 33   5.7         34                                    The Dark Tower   73211
# 34   7.3         67                                  T2 Trainspotting   72515
# 35   6.6         29                                            Bright   72504
# 36   6.4         50                                     The Boss Baby   65937
# 37   5.2         42                        xXx: Return of Xander Cage   64653
# 38   7.2         65                                     American Made   64034
# 39   6.8         52                      Murder on the Orient Express   61987
# 40   4.6         33                               Fifty Shades Darker   61807
# 41   6.3         49                                   Despicable Me 3   60851
# 42   6.6         62                               Annabelle: Creation   60136
#
#           year
# 0       (2017)
# 1       (2017)
# 2       (2017)
# 3       (2017)
# 4       (2017)
# 5       (2017)
# 6       (2017)
# 7   (I) (2017)
# 8   (I) (2017)
# 9       (2017)
# 10      (2017)
# 11      (2017)
# 12      (2017)
# 13      (2017)
# 14      (2017)
# 15      (2017)
# 16      (2017)
# 17      (2017)
# 18      (2017)
# 19  (I) (2017)
# 20      (2017)
# 21      (2017)
# 22      (2017)
# 23      (2017)
# 24      (2017)
# 25      (2017)
# 26      (2017)
# 27      (2017)
# 28      (2017)
# 29      (2017)
# 30      (2017)
# 31      (2017)
# 32      (2017)
# 33      (2017)
# 34      (2017)
# 35  (I) (2017)
# 36      (2017)
# 37      (2017)
# 38      (2017)
# 39      (2017)
# 40      (2017)
# 41      (2017)
# 42      (2017)

# %% [markdown]
# ## Script pour toutes les pages

# %%
pages = [str(i) for i in range (1,5)]
years_url = [str(i) for i in range(2000,2018)]
pages
# Out:
# ['1', '2', '3', '4']

# %% [markdown]
# ## Contrôler le taux de requêtes envoyées

# %%
from time import sleep
from random import randint

for a in range(0,5):
    print('Booh')
    sleep(randint(1,4))
# Out:
# Booh
# Booh
# Booh
# Booh
# Booh

# %%
from time import time
from IPython.display import clear_output
start_time = time() # on fixe le temps de début
requests = 0 # compter le nombre de requêtes
for _ in range(5):
    requests += 1    # increment la variable request de 1 chaque passage de boucle
    sleep(randint(1,3))
    elapsed_time = time() - start_time # calcul du temps ecoulé pour chque requête
    print('Request: {}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
    clear_output(wait = True)
# Out:
# Request: 5; Frequency: 0.4535448067195719 requests/s

# %%
from warnings import warn
warn('Attention')
# Out:
# /Users/guillaumedueymes/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Attention
