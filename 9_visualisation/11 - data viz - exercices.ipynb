# %% [markdown]
# <h1>TP Data visualisation </h1>
#
# Digimon, abréviation de "monstres numériques", est une franchise qui s'articule autour d'une mécanique de base qui consiste à capturer, soigner et entraîner les monstres pour ensuite s'engager dans le combat avec eux. C'est similaire aux Pokémon. <br>
#
# Ce fichier contient une liste de tous les Digimon du jeu, avec leur niveau, leur coquille, leur attribut, leur mémoire et le nombre de slots d'équipement. Toutes les statistiques (HP, SP, attaque, défense, intelligence et vitesse) sont pour ce Digimon au niveau 50.<br><br>
#
# pour toute la suite de cet exercice vous pouvez prendre pour modèle ce que nous avons fait pendant le cours (si vous êtes perdus). Et pour chaque questions n'hesitez pas à écrire vos observations/analyses ! <br><br>
#
# 1) importez le fichier DigiDB_digimonlist.csv et affichez le header<br>
# 2) A l'aide de la fonction .info() de pandas, vérifiez le type des colonnes et si des valeurs manquent dans certaines d'entre elle<br>
# 3) à l'aide de matplotlib, affichez un bar chart du nombre de digimons par niveau (Stage). <br>
# 4) faites le même exercice avec les attributs. Il y a plus de valeurs...adaptez la largeur du graphique pour que cela reste simple à consulter<br>
# 5) en utilisant sns.distplot, affichez la répartition de la colonne Memory<br>
# 6) en utiliant sns.kdeplot, affichez uniquement la courbe de répartition de la colonne 'Lv 50 HP'<br>
# 7) en utilisant scatter_matrix de Pandas, affichez la répartition et les nuages de point des 6 dernières colonnes du data set<br>
# 8) Il semble y avoir quelque chose d'intéréssant entre 'Lv50 SP' et 'Lv50 Int'...utilisez sns.jointplot pour voir cela plus en détail<br>
# 9) en utilisant sns.lmplot, ajoutez le niveau des digimons (Stage) sur le nuage de points réalisé en point 8.<br>
# 10) En utilisant sns.violinplot, visionnez la réparition de 'Lv 50 HP' en fonction du stage du digimon.<br>

# %% [markdown]
# 1) importez le fichier DigiDB_digimonlist.csv et affichez le header

# %%
import pandas as pd
data = pd.read_csv('DigiDB_digimonlist.csv',encoding='latin-1', sep=',')
data.head()
# Out:
#    Number  Digimon Stage  Type Attribute  Memory  Equip Slots  Lv 50 HP  \
# 0       1  Kuramon  Baby  Free   Neutral       2            0       590
# 1       2  Pabumon  Baby  Free   Neutral       2            0       950
# 2       3  Punimon  Baby  Free   Neutral       2            0       870
# 3       4  Botamon  Baby  Free   Neutral       2            0       690
# 4       5  Poyomon  Baby  Free   Neutral       2            0       540
#
#    Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# 0       77        79        69        68        95
# 1       62        76        76        69        68
# 2       50        97        87        50        75
# 3       68        77        95        76        61
# 4       98        54        59        95        86

# %% [markdown]
# 2) A l'aide de la fonction .info() de pandas, vérifiez le type des colonnes et si des valeurs manquent dans certaines d'entre elle

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 13 columns):
# Number         249 non-null int64
# Digimon        249 non-null object
# Stage          249 non-null object
# Type           249 non-null object
# Attribute      249 non-null object
# Memory         249 non-null int64
# Equip Slots    249 non-null int64
# Lv 50 HP       249 non-null int64
# Lv50 SP        249 non-null int64
# Lv50 Atk       249 non-null int64
# Lv50 Def       249 non-null int64
# Lv50 Int       249 non-null int64
# Lv50 Spd       249 non-null int64
# dtypes: int64(9), object(4)
# memory usage: 25.4+ KB

# %%
data.isnull().sum()/len(data)
# Out:
# Number         0.0
# Digimon        0.0
# Stage          0.0
# Type           0.0
# Attribute      0.0
# Memory         0.0
# Equip Slots    0.0
# Lv 50 HP       0.0
# Lv50 SP        0.0
# Lv50 Atk       0.0
# Lv50 Def       0.0
# Lv50 Int       0.0
# Lv50 Spd       0.0
# dtype: float64

# %% [markdown]
# 3) à l'aide de matplotlib, affichez un bar chart du nombre de digimons par niveau (Stage).

# %%
stages = data['Stage'].value_counts()
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(7,5))
ax1 = fig.add_subplot(111)
ax1.bar(range(len(stages)),stages)
tick_positions = range(0,len(stages))
ax1.set_xticks(tick_positions)
ax1.set_xticklabels(stages.index, rotation=45)
# Out:
# [Text(0, 0, 'Mega'),
#  Text(0, 0, 'Ultimate'),
#  Text(0, 0, 'Champion'),
#  Text(0, 0, 'Rookie'),
#  Text(0, 0, 'In-Training'),
#  Text(0, 0, 'Ultra'),
#  Text(0, 0, 'Baby'),
#  Text(0, 0, 'Armor')]

# %% [markdown]
# 4) faites le même exercice avec les attributs. Il y a plus de valeurs...adaptez la largeur du graphique pour que cela reste simple à consulter

# %%
Type = data['Attribute'].value_counts()

fig = plt.figure(figsize=(12,5))
ax1 = fig.add_subplot(111)
ax1.bar(range(len(Type)),Type)
tick_positions = range(0,len(Type))
ax1.set_xticks(tick_positions)
ax1.set_xticklabels(Type.index, rotation=45)
# Out:
# [Text(0, 0, 'Dark'),
#  Text(0, 0, 'Fire'),
#  Text(0, 0, 'Light'),
#  Text(0, 0, 'Neutral'),
#  Text(0, 0, 'Electric'),
#  Text(0, 0, 'Plant'),
#  Text(0, 0, 'Wind'),
#  Text(0, 0, 'Earth'),
#  Text(0, 0, 'Water')]

# %% [markdown]
# 5) en utilisant sns.distplot, affichez la répartition de la colonne Memory

# %%
import seaborn as sns
sns.distplot(data['Memory'])
sns.set()
plt.show()

# %% [markdown]
# 6) en utiliant sns.kdeplot, affichez uniquement la courbe de répartition de la colonne 'Lv 50 HP'

# %%
sns.kdeplot(data['Lv 50 HP'], shade = True)
sns.set()
plt.show()

# %% [markdown]
# 7) en utilisant scatter_matrix de Pandas, affichez la répartition et les nuages de point des 6 dernières colonnes du data set

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data[data.columns[-6:]], figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000010147208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000101EAA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000102010F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000102267B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010256160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010278AC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000000102A6470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000102CBE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000102CBE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010327128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001034CA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010379438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000000103A0DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000103CC748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000103FC0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010420A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001044C400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010475D68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000000104A1710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000104D10B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000104F4A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000105213C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010548D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000105756D8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000000105A4080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000105C79E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000105F6390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001061ACF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000106486A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010677048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000001069A9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000106C9358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000106EECC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010720668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010743FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001076F978>]],
#       dtype=object)

# %% [markdown]
# 8) Il semble y avoir quelque chose d'intéréssant entre 'Lv50 SP' et 'Lv50 Int'...utilisez sns.jointplot pour voir cela plus en détail

# %%
sns.jointplot("Lv50 SP", "Lv50 Int", data=data, kind="reg")
plt.show()

# %% [markdown]
# 9) en utilisant sns.lmplot, ajoutez le niveau des digimons (Stage) sur le nuage de points réalisé en point 8.

# %%
sns.lmplot(x="Lv50 SP", y= "Lv50 Int", hue="Stage", data=data, fit_reg = False)
plt.show()

# %% [markdown]
# 10) En utilisant sns.violinplot, visionnez la réparition de 'Lv 50 HP' en fonction du stage du digimon.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12,8)
sns.violinplot(x="Stage", y="Lv 50 HP", data=data)
plt.show()
