# %% [markdown]
# <h1> But de l'exerice </h1>
#
# L'objectif est d'apprendre à utiliser l'API restcountries, qui permet d'obtenir des données sur tous les Pays du monde. <br>
#
# 1) Faites une lecture rapide de la documentation de l'API : https://restcountries.eu/ <br>
# 2) Via requests.get et .content, tester le bon fonctionnement de l'API en requetant https://restcountries.eu/rest/v2/all. Récupérez vous bien des données ? Quel est code réponse de l'API ? <br>
# 3) Enregistrer le contenu de l'API dans la variable data. reformater data au format json grace à json.loads <br>
# 4) Créer un tableau pandas appelé dataSet, à partir de data et la fonction json_normalize. Visualisez les données. <br>
# 5) il y a beaucoup trop de données...nous allons simplifier cela. Refaire de même process d'appel mais cette fois avec cette API : https://restcountries.eu/rest/v2/alpha?codes=FRA . Il ne doit maintenir y avoir qu'une seul ligne correspondant aux infos sur la France<br>
# 6) Mettre l'information 'code' dans les paramètre d'appel de l'API (params=..) puis le supprimer de l'URL. <br>
# 7) Nous allons construire une fonction permettant d'obtenir une information précise sur un pays. <br>
# le comportement attendue est le suivant : la fonction infoPays('FRA','capital') devra retourner 'Paris' <br>
# 7-1) Déclarer la fonction infoPays qui prendra 2 paramètres : 'code', correspondant au code du pays et 'info' correspondant au contenu de la colonne à retourner (capital, monnaie...) <br>
# 7-2) placer dans la fonction l'appel à l'API réalisé à l'étape 6. la variable 'code' de l'api prendra la valeur du paramètre 'code' de la fonction infoPays <br>
# 7-3) Toujours dans la fonction créer ensuite la variable 'info' qui recupera la valeur de la colonne correspondant au paramètre 'info' de la fonction <br>
# 7-4) la fonction doit retourner la variable info en guise de réponse. <br>
# 8) quel est la capitale (capital) du bangladesh (BGD) ? <br>
# 9) quelle est la monnaie (currencies) de la Turquie(TUR) ?

# %% [markdown]
# 1) Faites une lecture rapide de la documentation de l'API : https://restcountries.eu/

# %% [markdown]
# 2) Via requests.get et .content, tester le bon fonctionnement de l'API en requetant https://restcountries.eu/rest/v2/all. Récupérez vous bien des données ? Quel est code réponse de l'API ?

# %%
import requests
url = 'https://restcountries.eu/rest/v2/all'
data = requests.get(url)
data
# Out:
# <Response [200]>

# %%
data.content
# Out:
# b'[{"name":"Afghanistan","topLevelDomain":[".af"],"alpha2Code":"AF","alpha3Code":"AFG","callingCodes":["93"],"capital":"Kabul","altSpellings":["AF","Af\xc4\xa1\xc4\x81nist\xc4\x81n"],"region":"Asia","subregion":"Southern Asia","population":27657145,"latlng":[33.0,65.0],"demonym":"Afghan","area":652230.0,"gini":27.8,"timezones":["UTC+04:30"],"borders":["IRN","PAK","TKM","UZB","TJK","CHN"],"nativeName":"\xd8\xa7\xd9\x81\xd8\xba\xd8\xa7\xd9\x86\xd8\xb3\xd8\xaa\xd8\xa7\xd9\x86","numericCode":"004","currencies":[{"code":"AFN","name":"Afghan afghani","symbol":"\xd8\x8b"}],"languages":[{"iso639_1":"ps","iso639_2":"pus","name":"Pashto","nativeName":"\xd9\xbe\xda\x9a\xd8\xaa\xd9\x88"},{"iso639_1":"uz","iso639_2":"uzb","name":"Uzbek","nativeName":"O\xca\xbbzbek"},{"iso639_1":"tk","iso639_2":"tuk","name":"Turkmen","nativeName":"T\xc3\xbcrkmen"}],"translations":{"de":"Afghanistan","es":"Afganist\xc3\xa1n","fr":"Afghanistan","ja":"\xe3\x82\xa2\xe3\x83\x95\xe3\x82\xac\xe3\x83\x8b\xe3\x82\xb9\xe3\x
# ...

# %% [markdown]
# 3) Enregistrer le contenu de l'API dans la variable data. reformater data au format json grace à json.loads

# %%
import requests
url = 'https://restcountries.eu/rest/v2/all'
import json
data = requests.get(url)
data = json.loads(data.content)
print(type(data))
data
# Out:
# <class 'list'>
# [{'name': 'Afghanistan',
#   'topLevelDomain': ['.af'],
#   'alpha2Code': 'AF',
#   'alpha3Code': 'AFG',
#   'callingCodes': ['93'],
#   'capital': 'Kabul',
#   'altSpellings': ['AF', 'Afġānistān'],
#   'region': 'Asia',
#   'subregion': 'Southern Asia',
#   'population': 27657145,
#   'latlng': [33.0, 65.0],
#   'demonym': 'Afghan',
#   'area': 652230.0,
#   'gini': 27.8,
#   'timezones': ['UTC+04:30'],
#   'borders': ['IRN', 'PAK', 'TKM', 'UZB', 'TJK', 'CHN'],
#   'nativeName': 'افغانستان',
#   'numericCode': '004',
#   'currencies': [{'code': 'AFN', 'name': 'Afghan afghani', 'symbol': '؋'}],
#   'languages': [{'iso639_1': 'ps',
#     'iso639_2': 'pus',
#     'name': 'Pashto',
#     'nativeName': 'پښتو'},
#    {'iso639_1': 'uz',
#     'iso639_2': 'uzb',
#     'name': 'Uzbek',
#     'nativeName': 'Oʻzbek'},
#    {'iso639_1': 'tk',
#     'iso639_2': 'tuk',
#     'name': 'Turkmen',
#     'nativeName': 'Türkmen'}],
#   'translations': {'de': 'Afghanistan',
# ...

# %% [markdown]
# 4) Créer un tableau pandas appelé dataSet, à partir de data et la fonction json_normalize. Visualisez les données.

# %%
from pandas.io.json import json_normalize
import json
data = requests.get(url)
data = json.loads(data.content)
dataSet = json_normalize(data)
dataSet.head(2)
# Out:
#   alpha2Code alpha3Code                     altSpellings      area  \
# 0         AF        AFG                 [AF, Afġānistān]  652230.0
# 1         AX        ALA  [AX, Aaland, Aland, Ahvenanmaa]    1580.0
#
#                           borders callingCodes    capital cioc  \
# 0  [IRN, PAK, TKM, UZB, TJK, CHN]         [93]      Kabul  AFG
# 1                              []        [358]  Mariehamn
#
#                                           currencies   demonym  ...  \
# 0  [{'code': 'AFN', 'name': 'Afghan afghani', 'sy...    Afghan  ...
# 1   [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]  Ålandish  ...
#
#   translations.br  translations.de translations.es translations.fa  \
# 0     Afeganistão      Afghanistan      Afganistán       افغانستان
# 1  Ilhas de Aland            Åland         Alandia      جزایر الند
#
#   translations.fr translations.hr translations.it  translations.ja  \
# 0     Afghanistan      Afganistan     Afghanistan          アフガニスタン
# ...

# %% [markdown]
# 5) il y a beaucoup trop de données...nous allons simplifier cela. Refaire de même process d'appel mais cette fois avec cette API : https://restcountries.eu/rest/v2/alpha?codes=FRA .

# %%
import requests
from pandas.io.json import json_normalize

url = 'https://restcountries.eu/rest/v2/alpha?codes=FRA'
data = requests.get(url)
data = json.loads(data.content)
dataSet = json_normalize(data)
dataSet
# Out:
#   alpha2Code alpha3Code                                 altSpellings  \
# 0         FR        FRA  [FR, French Republic, République française]
#
#        area                                   borders callingCodes capital  \
# 0  640679.0  [AND, BEL, DEU, ITA, LUX, MCO, ESP, CHE]         [33]   Paris
#
#   cioc                                        currencies demonym  ...  \
# 0  FRA  [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]  French  ...
#
#   translations.br  translations.de translations.es translations.fa  \
# 0          França       Frankreich         Francia          فرانسه
#
#   translations.fr translations.hr translations.it  translations.ja  \
# 0          France       Francuska         Francia             フランス
#
#   translations.nl translations.pt
# 0       Frankrijk          França
#
# [1 rows x 33 columns]

# %% [markdown]
# Il ne doit maintenant y avoir qu'une seul ligne correspondant aux infos sur la France.

# %% [markdown]
# 6) Mettre l'information 'code' dans les paramètre d'appel de l'API (params=..) puis le supprimer de l'URL.

# %%
import requests
from pandas.io.json import json_normalize

url = 'https://restcountries.eu/rest/v2/alpha/'
parametres = {
    'codes': 'FRA',
}

data = requests.get(url, params=parametres)
data = json.loads(data.content)
dataSet = json_normalize(data)
dataSet
# Out:
#   alpha2Code alpha3Code                                 altSpellings  \
# 0         FR        FRA  [FR, French Republic, République française]
#
#        area                                   borders callingCodes capital  \
# 0  640679.0  [AND, BEL, DEU, ITA, LUX, MCO, ESP, CHE]         [33]   Paris
#
#   cioc                                        currencies demonym  ...  \
# 0  FRA  [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]  French  ...
#
#   translations.br  translations.de translations.es translations.fa  \
# 0          França       Frankreich         Francia          فرانسه
#
#   translations.fr translations.hr translations.it  translations.ja  \
# 0          France       Francuska         Francia             フランス
#
#   translations.nl translations.pt
# 0       Frankrijk          França
#
# [1 rows x 33 columns]

# %% [markdown]
# 7) Nous allons construire une fonction permettant d'obtenir une information précise sur un pays.
# Le comportement attendue est le suivant : la fonction infoPays('FRA','capital') devra retourner 'Paris'
#
# 7-1) Déclarer la fonction infoPays qui prendra 2 paramètres : 'code', correspondant au code du pays et 'info' correspondant au contenu de la colonne à retourner (capital, monnaie...)
#
# 7-2) placer dans la fonction l'appel à l'API réalisé à l'étape 6. la variable 'code' de l'api prendra la valeur du paramètre 'code' de la fonction infoPays
#
# 7-3) Toujours dans la fonction créer ensuite la variable 'info' qui recupera la valeur de la colonne correspondant au paramètre 'info' de la fonction
#
# 7-4) la fonction doit retourner la variable info en guise de réponse.

# %%
def infoPays(code,info):
    parameters = {
    'codes': code,
    }
    url = 'https://restcountries.eu/rest/v2/alpha/'
    data = requests.get(url, params=parameters)
    data = json.loads(data.content)
    dataSet = json_normalize(data)
    info = dataSet[info][0]
    return info

# %% [markdown]
# 8) quel est la capitale (capital) du bangladesh (BGD) ?

# %%
infoPays('BGD','capital')
# Out:
# 'Dhaka'

# %%
infoPays('FRA','capital')
# Out:
# 'Paris'

# %% [markdown]
# 9) quelle est la monnaie (currencies) de la Turquie(TUR) ?

# %%
infoPays('TUR','currencies')
# Out:
# [{'code': 'TRY', 'name': 'Turkish lira', 'symbol': None}]
