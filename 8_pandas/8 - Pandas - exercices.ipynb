# %% [markdown]
# <b>Analyse d'un listing de 10 000 chaussures vendues en ligne</b>
#
# source du dataset : https://www.kaggle.com/datafiniti/womens-shoes-prices
#
# Nous allons analyser un data set contenant 10 000 chaussures avec de nombreuse caractéristiques comme le prix, les couleurs disponibles, les tailles disponibles, leurs poids...
#
# Voici une traduction de la description des colonnes principales :
# - asins : Une liste des ASIN (identificateurs d'Amazon) utilisés pour ce produit.
# - brand : Le nom de marque de ce produit.
# - categories : Une liste de mots-clés de catégorie utilisés pour ce produit dans plusieurs sources.
# - colors : Une liste de couleurs disponibles pour ce produit.
# - count : Le nombre d'unités incluses dans l'emballage du produit. Peut inclure une description de l'unité.
# - dateAdded : La date à laquelle ce produit a été ajouté pour la première fois à la base de données des produits.
# - dateUpdated : La date la plus récente à laquelle ce produit a été mis à jour ou vu par notre système.
# - descriptions : Une liste des descriptions de ce produit provenant de diverses sources. Chaque description contient :
# - dimension : La longueur, la largeur et la hauteur de ce produit. Unités incluses.
# - ean : Les codes EAN de ce produit. Il peut y avoir plus d'un EAN dans la liste lorsqu'un produit a plusieurs variantes,
# - financingAndLeasing : Une liste des conditions de financement ou de location associées à ce produit
# - features : Une liste des caractéristiques associées à ce produit. La liste des caractéristiques peut être obtenue à partir des sections de caractéristiques spécifiques disponibles dans la liste des produits du produit.
# - manufacturer : Numéro du fabricant
# - merchants : Une liste des marchands qui vendent ce produit. Il s'agit généralement de marchands tiers que l'on trouve sur les sites Web de commerce électronique.
# - name : dénomination du produit
# - prices : Une liste de prix pour ce produit.
# - primaryCategories : Une liste des catégories normalisées auxquelles ce produit appartient. Les valeurs des catégories peuvent être trouvées ici.
# - quantities : Une liste des quantités disponibles pour ce produit. Les quantités indiquent combien d'unités du produit sont disponibles auprès d'une source spécifique à un moment donné.
# - reviews : Une liste de commentaires pour ce produit.
# - sizes : Une liste des tailles disponibles pour ce produit.
# - skus : Une liste des références de ce produit. Les SKU sont typiquement spécifiques aux détaillants individuels ou aux sites Web.
# - sourceURLs : Une liste d'URLs utilisées pour générer les données de ce produit.
# - upc : Le code CUP de ce produit.
# - websiteIDs : Une liste d'identifiants de site Web pour ce produit. Les ID de site Web sont liés à un détaillant en ligne spécifique. Il s'agit de l'identifiant unique utilisé par le site Web. Ils sont utilisés par Datafiniti lorsque d'autres identificateurs uniques ne sont pas disponibles pour un produit.
# - weight : Le poids du produit. Unités incluses.
#
# La source https://developer.datafiniti.co/docs/product-data-schema

# %% [markdown]
# <b> Exercices </b>
#
# <b>Découverte du data set</b><br>
# 1) à l'aide de la fonction read_csv, importez entièrement le data set de enregistrez dans le dataframe 'Shoes' <br>
# 2) Utilisez la méthode .head() pour afficher les premières lignes <br>
# 3) Il y a trop de colonnes...Pour avoir une vue d'ensemble changez le paramétrage de pandas avec set_option pour afficher les 34 colonnes. Une fois cela fait, affichez à nouveau le head de la page <br>
# 4) On va garder uniquement les colonnes qui nous interessent. grace à la méthode de sélection de plusieurs colonnes, créez un dataframe 'ShoesLight', comprenant unique les colonnes suivantes :'id','name','dateUpdated','colors','prices.amountMax','prices.amountMin','prices.merchant'. <br>Affichez le head de ShoesLight.<br>
#
# <b> data cleaning </b> <br>
# 5) A l'aide de la méthode .dtypes, consultez les types de chaque colonne. Ecrivez en markdown celles devant être corrigées et comment. <br>
# 6) A l'aide des méthodes .isnull, .sum() et len(), calculez le % de valeurs maquantes par colonne. Notez en markdown celles qui sont problématiques. <br>
# 7) Il manque trop de valeurs pour les colonnes des e-commercant et des couleurs. Retirez les du dataframe shoesLight <br>
# 8) A l'aide de la méthode .to_datetime, transformez la colonne 'dateUpdated'
#
# <b> features modeling </b> <br>
# 9) caculez la colonne 'prices.amountAverage' en additionnant les colonnes 'prices.amountMax' et 'prices.amountMin' et en divisant par 2 <br>
# 10) grace à la méthode dt.weekday, créez une colonne 'dayOfweekUpdated', permettant de connaitre à partir de dateUpdated le jour de la semaine où les produits sont mis à jour
#
# <b> data analyse </b> <br>
#
# 11) Analyser le prix moyen des chaussures avec la methode .desribe() <br>
# 12) Y-a-t-il de grandes différences de prix en fonction de la marque ? A l'aide des methodes groupby(), mean() et sort_values(), créez une varaible 'Luxe' contenant les 10 marques les plus chères, puis la variable 'lowCost' contenant les 10 marques les moins chères. <br>
# 13) grace à la méthode value_counts(), determinez le jour de la semaine où les produits sont le plus souvent mis à jour <br>
# 14) (optionnel) donnez le prix moyen des produits de la marque 'easy street' mis à jour un jeudi

# %% [markdown]
# <b>Découverte du data set</b><br>

# %%
import pandas as pd 
shoes = pd.read_csv('Datafiniti_Womens_Shoes.csv', encoding = 'latin-1', sep=',')
pd.set_option("display.max_columns", 35)
shoes.head()
# Out:
#                      id             dateAdded           dateUpdated asins  \
# 0  AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z   NaN
# 1  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 2  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 3  AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z   NaN
# 4  AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z   NaN
#
#          brand                                         categories  \
# 0  Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
#
#   primaryCategories                          colors                 dimension  \
# 0             Shoes  Silver,Cream Watercolor Floral                       NaN
# 1             Shoes                            Grey                       NaN
# 2             Shoes                            Grey                       NaN
# 3       Shoes,Shoes                           Black  6.0 in x 6.0 in x 1.0 in
# 4             Shoes                            Grey  6.0 in x 6.0 in x 1.0 in
#
#             ean                                          imageURLs  \
# 0           NaN  https://i5.walmartimages.com/asr/861ca6cf-fa55...
# 1  3.397705e+10  https://i5.walmartimages.com/asr/421de5d5-3a74...
# 2  3.397705e+10  https://i5.walmartimages.com/asr/421de5d5-3a74...
# 3  3.397705e+10  https://i5.walmartimages.com/asr/950d38a5-0113...
# 4  3.397705e+10  https://i5.walmartimages.com/asr/5e137bc3-c900...
#
#                                                 keys manufacturer  \
# 0  naturalizer/47147sc022,017136472311,womensnatu...          NaN
# 1  mukluks/00173650206,033977045743,muklukswomens...     Muk Luks
# 2  mukluks/00173650206,033977045743,muklukswomens...     Muk Luks
# 3  033977045903,muklukswomensdawnsuedescuffslippe...     Muk Luks
# 4  mukluks/00173660206,033977045958,0033977045958...          NaN
#
#   manufacturerNumber                                               name  \
# 0         47147SC022  Naturalizer Danya Women N/S Open Toe Synthetic...
# 1       0017365020-6                MUK LUKS Womens Jane Suede Moccasin
# 2       0017365020-6                MUK LUKS Womens Jane Suede Moccasin
# 3       0017366001-6           MUK LUKS Womens Dawn Suede Scuff Slipper
# 4       0017366020-6           MUK LUKS Womens Dawn Suede Scuff Slipper
#
#    prices.amountMax  prices.amountMin prices.availability        prices.color  \
# 0             55.99             55.99                 NaN  UWomens  M Regular
# 1             47.00             35.25            In Stock                Grey
# 2             35.25             35.25            In Stock                Grey
# 3             24.75             24.75            In Stock               Black
# 4             33.00             30.39            In Stock                Grey
#
#   prices.condition prices.currency      prices.dateAdded  \
# 0              NaN             USD  2017-03-28T11:40:25Z
# 1              New             USD  2018-01-03T05:21:54Z
# 2              New             USD  2017-12-06T05:02:42Z
# 3              New             USD  2018-01-04T11:52:35Z
# 4              New             USD  2017-12-04T21:35:47Z
#
#                                      prices.dateSeen  prices.isSale  \
# 0  2017-03-25T09:19:24.819Z,2017-03-25T09:19:19.600Z          False
# 1  2017-12-08T14:24:00.000Z,2017-11-01T02:52:00.000Z           True
# 2  2017-11-10T15:11:00.000Z,2017-11-18T08:00:00.000Z          False
# 3                           2017-12-07T16:37:00.000Z          False
# 4                           2017-11-17T21:15:00.000Z           True
#
#     prices.merchant prices.offer  prices.returnPolicy prices.shipping  \
# 0     Overstock.com          NaN                  NaN             NaN
# 1       Walmart.com          NaN                  NaN        Standard
# 2  Slippers Dot Com          NaN                  NaN           Value
# 3  Slippers Dot Com          NaN                  NaN           Value
# 4       Walmart.com          NaN                  NaN       Expedited
#
#   prices.size                                  prices.sourceURLs  \
# 0           S  https://www.overstock.com/Clothing-Shoes/Women...
# 1           6  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# 2           6  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# 3           6  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
# 4           6  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
#
#                                                sizes  \
# 0  6W,9W,7.5W,12W,8.5M,9N,9M,9.5M,10.5M,10W,8.5W,...
# 1                                         10,7,6,9,8
# 2                                         10,7,6,9,8
# 3                                         10,7,6,9,8
# 4                                         10,7,6,9,8
#
#                                           sourceURLs           upc weight
# 0  https://www.walmart.com/ip/Naturalizer-Danya-W...  017136472311    NaN
# 1  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...  033977045743    NaN
# 2  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...  033977045743    NaN
# 3  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...  033977045903    NaN
# 4  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...  033977045958    NaN

# %%
shoesLight = shoes[['id','name','dateUpdated','colors','prices.amountMax','prices.amountMin','prices.merchant']]
shoesLight
# Out:
#                         id                                               name  \
# 0     AVpfEf_hLJeJML431ueH  Naturalizer Danya Women N/S Open Toe Synthetic...
# 1     AVpi74XfLJeJML43qZAc                MUK LUKS Womens Jane Suede Moccasin
# 2     AVpi74XfLJeJML43qZAc                MUK LUKS Womens Jane Suede Moccasin
# 3     AVpjXyCc1cnluZ0-V-Gj           MUK LUKS Womens Dawn Suede Scuff Slipper
# 4     AVphGKLPilAPnD_x1Nrm           MUK LUKS Womens Dawn Suede Scuff Slipper
# 5     AVpg91ziilAPnD_xziOo  Women's MUK LUKSÂ¬Ã Soft Ones Sock Money Slip...
# 6     AVpjGKXyLJeJML43r8BH              Women's MUK LUKSÂ¬Ã Faux Suede Clogs
# 7     AVpjGKXyLJeJML43r8BH              Women's MUK LUKSÂ¬Ã Faux Suede Clogs
# 8     AVpfLXyhilAPnD_xWmNc                       MUK LUKS Women's Malena Boot
# 9     AVpfeWdJ1cnluZ0-lXYU                       MUK LUKS Women's Malena Boot
# 10    AVpfeWdJ1cnluZ0-lXYU                       MUK LUKS Women's Malena Boot
# 11    AVpf38PKLJeJML43FRwO                       MUK LUKS Women's Hayden Boot
# 12    AVph9abqilAPnD_x_Nrp                         MUK LUKS Women's Demi Boot
# 13    AVph9abqilAPnD_x_Nrp                         MUK LUKS Women's Demi Boot
# 14    AVpgNGD6ilAPnD_xpAke                        MUK LUKS Women's Nikki Boot
# 15    AVpgBzl41cnluZ0-vSQf                MUK LUKS Women's Elle Wedge Sandals
# 16    AVpgBzl41cnluZ0-vSQf                MUK LUKS Women's Elle Wedge Sandals
# 17    AVpgBzl41cnluZ0-vSQf                MUK LUKS Women's Elle Wedge Sandals
# 18    AVpivUm2ilAPnD_xHGfN                       MUK LUKS Women's Patti Boots
# 19    AVpivUm2ilAPnD_xHGfN                       MUK LUKS Women's Patti Boots
# 20    AV_NPBzfHh53nbDRAFPa                  MUK LUKS Chrystal Women's Sandals
# 21    AVpfGWT3ilAPnD_xU7MQ    Sloggers Women's Outfitters Premium Garden Clog
# 22    AVphXIhELJeJML43Z-74                     Dr. Scholl's Women's Freestyle
# 23    AVphX0ZbLJeJML43aHNG            Genuine Dickies Womens' Real Suede Clog
# 24    AVpjDTKT1cnluZ0-TF44            Mo Mo Women's Cami Studded Thong Sandal
# 25    AVphf6M51cnluZ0-DNIG               MOMO Women's Low Heel Lace Up Bootie
# 26    AVpfk-Q81cnluZ0-nUsT          Mo Mo Women's Outlander Heeled Hiker Boot
# 27    AV-ncxniKZqtpbFMS0GX  Skechers Women's Skech-Air Lingle Black Memory...
# 28    AV-ncxniKZqtpbFMS0GX  Skechers Women's Skech-Air Lingle Black Memory...
# 29    AV14CA98vKc47QAVnx6N  76580 W Wide Width Black Skechers Shoe New Wom...
# ...                    ...                                                ...
# 9970  AWKb6Og9Hh53nbDRIg_U       SeaVees Ocean Park Espadrille Shoe - Women's
# 9971  AWKb6PqiYSSHbkXwyzQD                           UGG Sammy Shoe - Women's
# 9972  AWKb6PqiYSSHbkXwyzQD                           UGG Sammy Shoe - Women's
# 9973  AWKb4IazYSSHbkXwyyiK      New Balance Fresh Foam Gobi V2 Shoe - Women's
# 9974  AWKb4IazYSSHbkXwyyiK      New Balance Fresh Foam Gobi V2 Shoe - Women's
# 9975  AWKb4IazYSSHbkXwyyiK      New Balance Fresh Foam Gobi V2 Shoe - Women's
# 9976  AWKb6Z2VYSSHbkXwyzTm                  Toms Jutti D'Orsay Shoe - Women's
# 9977  AWKb6Z2VYSSHbkXwyzTm                  Toms Jutti D'Orsay Shoe - Women's
# 9978  AWKb37yYYSSHbkXwyyeJ                 Olukai Waialua Mesh Shoe - Women's
# 9979  AWKb37yYYSSHbkXwyyeJ                 Olukai Waialua Mesh Shoe - Women's
# 9980  AWKb4e6gHh53nbDRIgZV                Vans Ultrarange Gore Shoe - Women's
# 9981  AWKb546EHh53nbDRIg37              Bogs Sweet Pea Slip On Shoe - Women's
# 9982  AWKb4fdgYSSHbkXwyypf               Toms Venice Alpargata Shoe - Women's
# 9983  AWKb4fdgYSSHbkXwyypf               Toms Venice Alpargata Shoe - Women's
# 9984  AWKb4fdgYSSHbkXwyypf               Toms Venice Alpargata Shoe - Women's
# 9985  AWKb4fdgYSSHbkXwyypf               Toms Venice Alpargata Shoe - Women's
# 9986  AWKb4fdgYSSHbkXwyypf               Toms Venice Alpargata Shoe - Women's
# 9987  AWKb4fdgYSSHbkXwyypf               Toms Venice Alpargata Shoe - Women's
# 9988  AWKb5Z0ZYSSHbkXwyy9w       Lowa San Luis Gtx Surround Lo Shoe - Women's
# 9989  AWKb5Z0ZYSSHbkXwyy9w       Lowa San Luis Gtx Surround Lo Shoe - Women's
# 9990  AWKb5Z0ZYSSHbkXwyy9w       Lowa San Luis Gtx Surround Lo Shoe - Women's
# 9991  AWKb5Z0ZYSSHbkXwyy9w       Lowa San Luis Gtx Surround Lo Shoe - Women's
# 9992  AWKb5Z0ZYSSHbkXwyy9w       Lowa San Luis Gtx Surround Lo Shoe - Women's
# 9993  AWKb5Z0ZYSSHbkXwyy9w       Lowa San Luis Gtx Surround Lo Shoe - Women's
# 9994  AWKb5Z0ZYSSHbkXwyy9w       Lowa San Luis Gtx Surround Lo Shoe - Women's
# 9995  AWKcCm-RHh53nbDRIh1_     Asics Gel-Foundation 12 Running Shoe - Women's
# 9996  AWKcEq-dHh53nbDRIiES       Asics Gel-Fortitude 7 Running Shoe - Women's
# 9997  AWKb5jmLYSSHbkXwyzBA                Kaanas Mesa Hardware Mule - Women's
# 9998  AWKcEIInYSSHbkXwy0SA  Nike Air Zoom Structure 21 Running Shoe - Narr...
# 9999  AWKb6PiKYSSHbkXwyzP-       OTZShoes Espadrille Shearling Shoe - Women's
#
#                dateUpdated                                             colors  \
# 0     2018-01-29T04:38:43Z                     Silver,Cream Watercolor Floral
# 1     2018-01-03T05:21:54Z                                               Grey
# 2     2018-01-03T05:21:54Z                                               Grey
# 3     2018-01-04T11:52:35Z                                              Black
# 4     2018-01-18T03:55:18Z                                               Grey
# 5     2018-10-23T21:26:11Z                                        Brown Tweed
# 6     2018-10-15T15:50:13Z  Light Blue,Brown,Navy,Purple,Burgundy,Black,Na...
# 7     2018-10-15T15:50:13Z  Light Blue,Brown,Navy,Purple,Burgundy,Black,Na...
# 8     2018-01-03T05:22:07Z                                          Navy,Grey
# 9     2018-01-30T06:18:34Z                                              Brown
# 10    2018-01-30T06:18:34Z                                              Brown
# 11    2018-01-23T04:13:40Z                                 Black,Medium Beige
# 12    2018-01-04T11:52:59Z                     Grey,Dark Brown,Chestnut,Brown
# 13    2018-01-04T11:52:59Z                     Grey,Dark Brown,Chestnut,Brown
# 14    2018-01-04T08:03:19Z                              Grey,Dark Brown,Taupe
# 15    2018-01-28T10:16:47Z                                  Black,Grey,Pewter
# 16    2018-01-28T10:16:47Z                                  Black,Grey,Pewter
# 17    2018-01-28T10:16:47Z                                  Black,Grey,Pewter
# 18    2018-01-28T10:52:04Z  Charcoal Gray,Grey,Dark Brown,Moccasin,Light G...
# 19    2018-01-28T10:52:04Z  Charcoal Gray,Grey,Dark Brown,Moccasin,Light G...
# 20    2018-01-09T21:18:52Z                                              White
# 21    2018-06-05T22:29:16Z                                N/a,Kiwi,Blue,Black
# 22    2018-01-04T11:52:59Z                                              Black
# 23    2018-01-04T08:02:27Z                                          Black,Tan
# 24    2018-01-04T08:03:26Z                                      Black,Fuchsia
# 25    2018-01-03T05:21:54Z                                        Black,Brown
# 26    2018-01-03T05:21:54Z                                           Buckskin
# 27    2018-04-21T12:44:31Z                                              Black
# 28    2018-04-21T12:44:31Z                                              Black
# 29    2018-04-21T12:44:03Z                                              Black
# ...                    ...                                                ...
# 9970  2018-04-06T21:35:55Z                                 Birch,Black,Marine
# 9971  2018-04-06T21:35:47Z                                Slate,Black Heather
# 9972  2018-04-06T21:35:47Z                                Slate,Black Heather
# 9973  2018-04-06T21:35:46Z                                               Fiji
# 9974  2018-04-06T21:35:46Z                                               Fiji
# 9975  2018-04-06T21:35:46Z                                               Fiji
# 9976  2018-04-06T21:35:43Z  Honey Leather/Blue Chambray,Black Leather/Cham...
# 9977  2018-04-06T21:35:43Z  Honey Leather/Blue Chambray,Black Leather/Cham...
# 9978  2018-04-06T21:35:38Z            Dark Shadow/Dark Shadow,Mustang/Mustang
# 9979  2018-04-06T21:35:38Z            Dark Shadow/Dark Shadow,Mustang/Mustang
# 9980  2018-04-06T21:35:37Z                                   Black,True White
# 9981  2018-04-06T21:35:36Z                                         Black,Wine
# 9982  2018-04-06T21:35:34Z  Black Cherry Heritage Canvas,Mojolica Blue Her...
# 9983  2018-04-06T21:35:34Z  Black Cherry Heritage Canvas,Mojolica Blue Her...
# 9984  2018-04-06T21:35:34Z  Black Cherry Heritage Canvas,Mojolica Blue Her...
# 9985  2018-04-06T21:35:34Z  Black Cherry Heritage Canvas,Mojolica Blue Her...
# 9986  2018-04-06T21:35:34Z  Black Cherry Heritage Canvas,Mojolica Blue Her...
# 9987  2018-04-06T21:35:34Z  Black Cherry Heritage Canvas,Mojolica Blue Her...
# 9988  2018-04-06T21:02:08Z                              Gray/Berry,Stone/Mint
# 9989  2018-04-06T21:02:08Z                              Gray/Berry,Stone/Mint
# 9990  2018-04-06T21:02:08Z                              Gray/Berry,Stone/Mint
# 9991  2018-04-06T21:02:08Z                              Gray/Berry,Stone/Mint
# 9992  2018-04-06T21:02:08Z                              Gray/Berry,Stone/Mint
# 9993  2018-04-06T21:02:08Z                              Gray/Berry,Stone/Mint
# 9994  2018-04-06T21:02:08Z                              Gray/Berry,Stone/Mint
# 9995  2018-04-06T21:02:04Z                              Silver/Pistachio/Pink
# 9996  2018-04-06T21:02:04Z                           Indigo Blue/Silver/Prune
# 9997  2018-04-06T21:02:01Z                                              Mauve
# 9998  2018-04-06T21:01:53Z                Armory Blue/Armory Navy-Cirrus Blue
# 9999  2018-04-06T21:01:50Z                                              Black
#
#       prices.amountMax  prices.amountMin   prices.merchant
# 0                55.99             55.99     Overstock.com
# 1                47.00             35.25       Walmart.com
# 2                35.25             35.25  Slippers Dot Com
# 3                24.75             24.75  Slippers Dot Com
# 4                33.00             30.39       Walmart.com
# 5                14.00              7.90       Walmart.com
# 6                24.00             12.79               NaN
# 7                24.00             12.79               NaN
# 8                59.00             39.88       Walmart.com
# 9                59.00             47.99       Walmart.com
# 10               59.00             36.99       Walmart.com
# 11               95.00             62.80       Shoebuy.com
# 12               68.00             41.27       Walmart.com
# 13               68.00             44.88       Walmart.com
# 14               69.00             44.88       Walmart.com
# 15               50.00             28.91       Walmart.com
# 16               50.00             29.91       Walmart.com
# 17               50.00             22.53       Walmart.com
# 18               57.00             57.00  Slippers Dot Com
# 19               59.00             42.88       Walmart.com
# 20               36.00             25.49               NaN
# 21               32.44             32.44       Walmart.com
# 22               32.98             32.98       Walmart.com
# 23               19.97             13.88       Walmart.com
# 24               24.00             13.88       Walmart.com
# 25               24.00             24.00       Walmart.com
# 26               36.00             28.40       Walmart.com
# 27               85.00             85.00               NaN
# 28               85.00             85.00               NaN
# 29               75.00             75.00               NaN
# ...                ...               ...               ...
# 9970             87.95             87.95   Backcountry.com
# 9971            109.95            109.95   Backcountry.com
# 9972            109.95            109.95   Backcountry.com
# 9973             99.95             99.95   Backcountry.com
# 9974             99.95             99.95   Backcountry.com
# 9975             99.95             99.95   Backcountry.com
# 9976             84.95             84.95   Backcountry.com
# 9977             84.95             84.95   Backcountry.com
# 9978             80.00             80.00   Backcountry.com
# 9979             80.00             80.00   Backcountry.com
# 9980             84.95             84.95   Backcountry.com
# 9981             64.99             64.99   Backcountry.com
# 9982             47.95             47.95   Backcountry.com
# 9983             47.95             47.95   Backcountry.com
# 9984             47.95             47.95   Backcountry.com
# 9985             47.95             47.95   Backcountry.com
# 9986             47.95             47.95   Backcountry.com
# 9987             47.95             47.95   Backcountry.com
# 9988            199.95            109.97   Backcountry.com
# 9989            199.95             89.98   Backcountry.com
# 9990            199.95             89.98   Backcountry.com
# 9991            199.95             89.98   Backcountry.com
# 9992            199.95             89.98   Backcountry.com
# 9993            199.95             89.98   Backcountry.com
# 9994            199.95             89.98   Backcountry.com
# 9995            119.95             89.96   Backcountry.com
# 9996            119.95             77.97   Backcountry.com
# 9997            128.95             64.47   Backcountry.com
# 9998            119.95             89.96   Backcountry.com
# 9999             99.95             49.97   Backcountry.com
#
# [10000 rows x 7 columns]

# %%
shoesLight.dtypes
# Out:
# id                   object
# name                 object
# dateUpdated          object
# colors               object
# prices.amountMax    float64
# prices.amountMin    float64
# prices.merchant      object
# dtype: object

# %% [markdown]
# - dateUpdated doit etre passé en datetime
# - colors doit etre passé en liste

# %%
shoesLight.isnull().sum()/len(shoesLight)
# Out:
# id                  0.0000
# name                0.0000
# dateUpdated         0.0000
# colors              0.7369
# prices.amountMax    0.0000
# prices.amountMin    0.0000
# prices.merchant     0.9565
# dtype: float64

# %% [markdown]
# Il manque 75% des valeurs pour les couelurs et quasi tous les noms des e-commercants.

# %%
shoesLight = shoes[['id','name','brand','dateUpdated','prices.amountMax','prices.amountMin']]
shoesLight.head()
# Out:
#                      id                                               name  \
# 0  AVpfEf_hLJeJML431ueH  Naturalizer Danya Women N/S Open Toe Synthetic...
# 1  AVpi74XfLJeJML43qZAc                MUK LUKS Womens Jane Suede Moccasin
# 2  AVpi74XfLJeJML43qZAc                MUK LUKS Womens Jane Suede Moccasin
# 3  AVpjXyCc1cnluZ0-V-Gj           MUK LUKS Womens Dawn Suede Scuff Slipper
# 4  AVphGKLPilAPnD_x1Nrm           MUK LUKS Womens Dawn Suede Scuff Slipper
#
#          brand           dateUpdated  prices.amountMax  prices.amountMin
# 0  Naturalizer  2018-01-29T04:38:43Z             55.99             55.99
# 1     MUK LUKS  2018-01-03T05:21:54Z             47.00             35.25
# 2     MUK LUKS  2018-01-03T05:21:54Z             35.25             35.25
# 3     MUK LUKS  2018-01-04T11:52:35Z             24.75             24.75
# 4     MUK LUKS  2018-01-18T03:55:18Z             33.00             30.39

# %%
shoesLight['dateUpdated'] = pd.to_datetime(shoesLight['dateUpdated'])
shoesLight['dateUpdated']
# Out:
# D:\Utilisateurs\guillaume\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 0      2018-01-29 04:38:43+00:00
# 1      2018-01-03 05:21:54+00:00
# 2      2018-01-03 05:21:54+00:00
# 3      2018-01-04 11:52:35+00:00
# 4      2018-01-18 03:55:18+00:00
# 5      2018-10-23 21:26:11+00:00
# 6      2018-10-15 15:50:13+00:00
# 7      2018-10-15 15:50:13+00:00
# 8      2018-01-03 05:22:07+00:00
# 9      2018-01-30 06:18:34+00:00
# 10     2018-01-30 06:18:34+00:00
# 11     2018-01-23 04:13:40+00:00
# 12     2018-01-04 11:52:59+00:00
# 13     2018-01-04 11:52:59+00:00
# 14     2018-01-04 08:03:19+00:00
# 15     2018-01-28 10:16:47+00:00
# 16     2018-01-28 10:16:47+00:00
# 17     2018-01-28 10:16:47+00:00
# 18     2018-01-28 10:52:04+00:00
# 19     2018-01-28 10:52:04+00:00
# 20     2018-01-09 21:18:52+00:00
# 21     2018-06-05 22:29:16+00:00
# 22     2018-01-04 11:52:59+00:00
# 23     2018-01-04 08:02:27+00:00
# 24     2018-01-04 08:03:26+00:00
# 25     2018-01-03 05:21:54+00:00
# 26     2018-01-03 05:21:54+00:00
# 27     2018-04-21 12:44:31+00:00
# 28     2018-04-21 12:44:31+00:00
# 29     2018-04-21 12:44:03+00:00
#                   ...
# 9970   2018-04-06 21:35:55+00:00
# 9971   2018-04-06 21:35:47+00:00
# 9972   2018-04-06 21:35:47+00:00
# 9973   2018-04-06 21:35:46+00:00
# 9974   2018-04-06 21:35:46+00:00
# 9975   2018-04-06 21:35:46+00:00
# 9976   2018-04-06 21:35:43+00:00
# 9977   2018-04-06 21:35:43+00:00
# 9978   2018-04-06 21:35:38+00:00
# 9979   2018-04-06 21:35:38+00:00
# 9980   2018-04-06 21:35:37+00:00
# 9981   2018-04-06 21:35:36+00:00
# 9982   2018-04-06 21:35:34+00:00
# 9983   2018-04-06 21:35:34+00:00
# 9984   2018-04-06 21:35:34+00:00
# 9985   2018-04-06 21:35:34+00:00
# 9986   2018-04-06 21:35:34+00:00
# 9987   2018-04-06 21:35:34+00:00
# 9988   2018-04-06 21:02:08+00:00
# 9989   2018-04-06 21:02:08+00:00
# 9990   2018-04-06 21:02:08+00:00
# 9991   2018-04-06 21:02:08+00:00
# 9992   2018-04-06 21:02:08+00:00
# 9993   2018-04-06 21:02:08+00:00
# 9994   2018-04-06 21:02:08+00:00
# 9995   2018-04-06 21:02:04+00:00
# 9996   2018-04-06 21:02:04+00:00
# 9997   2018-04-06 21:02:01+00:00
# 9998   2018-04-06 21:01:53+00:00
# 9999   2018-04-06 21:01:50+00:00
# Name: dateUpdated, Length: 10000, dtype: datetime64[ns, UTC]

# %%
shoesLight['prices.amountAverage'] =  (shoesLight['prices.amountMax'] + shoesLight['prices.amountMin']) / 2
shoesLight['prices.amountAverage'].head()
# Out:
# D:\Utilisateurs\guillaume\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 0    55.990
# 1    41.125
# 2    35.250
# 3    24.750
# 4    31.695
# Name: prices.amountAverage, dtype: float64

# %%
shoesLight['prices.amountAverage'].describe()
# Out:
# count    10000.000000
# mean        60.177376
# std         18.786193
# min          5.375000
# 25%         49.990000
# 50%         56.875000
# 75%         67.490000
# max        359.950000
# Name: prices.amountAverage, dtype: float64
